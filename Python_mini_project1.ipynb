# %%
# Project 1: Smart Traffic Fine Management System 
# Project Description: 
# Build a Python program that helps a traffic police department automatically calculate fines for drivers 
# based on their speed, age, and seatbelt usage. 
# Requirements: 
# 1. Inputs: 
# o Driver Name 
# o Driver Age 
# o Speed of the Vehicle (in km/h) 
# o Whether the driver was wearing a seatbelt (yes or no) 
# 2. Logic & Conditions: 
# o Speed Limit: 60 km/h 
# o Fine Rules: 
# ▪ If speed > 60 and ≤ 80 → Fine ₹500 
# ▪ If speed > 80 and ≤ 100 → Fine ₹1000 
# ▪ If speed > 100 → Fine ₹2000 
# o If no seatbelt → Add ₹500 to the fine. 
# o If driver age < 18 → Display: "Underage driving is illegal. Report to higher authority." 
# o If no fine → Display: "No fine. Drive safely!" 
# 3. Output: 
# o Driver name 
# o Age 
# o Speed 
# o Seatbelt status 
# o Fine amount (if applicable) 
# o Final message

# %%
while True:
    print("\n--- Enter Driver Details ---")

    name = input("Enter Driver Name: ")
    age = int(input("Enter Driver Age: "))
    speed = float(input("Enter Vehicle Speed (km/h): "))
    seatbelt = input("Seatbelt worn (yes/no): ").lower()

    fine = 0
    message = ""

    if age < 18:
        message = "Underage driving is illegal. Report to higher authority."

    else:
        # Speed-based fine
        if speed > 60 and speed <= 80:
            fine = 500
        elif speed > 80 and speed <= 100:
            fine = 1000
        elif speed > 100:
            fine = 2000

        # Seatbelt fine
        if seatbelt == "no":
            fine += 500

        # Final message
        if fine == 0:
            message = "No fine. Drive safely!"
        else:
            message = f"Fine : ₹{fine}"

    print("\n--- Traffic Fine Report ---")
    print(f"Driver Name     : {name}")
    print(f"Driver Age      : {age}")
    print(f"Vehicle Speed   : {speed} km/h")
    print(f"Seatbelt Status : {seatbelt}")
    print(f"Message         : {message}")

    choice = input("\nDo you want to add another driver? (yes/no): ").lower()
    if choice != "yes":
        print("\nThank you! Program ended.")
        break
# Out:
# --- Enter Driver Details ---
# Enter Driver Name:  pratik
# Enter Driver Age:  45
# Enter Vehicle Speed (km/h):  80
# Seatbelt worn (yes/no):  no
# --- Traffic Fine Report ---
# Driver Name     : pratik
# Driver Age      : 45
# Vehicle Speed   : 80.0 km/h
# Seatbelt Status : no
# Message         : Fine imposed: ₹1000
# Do you want to add another driver? (yes/no):  no
# Thank you! Program ended.
